# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenparida/18cse200/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="https://raw.githubusercontent.com/naveenparida/18cse200/main/BankChurners.csv"

# %%
data=pd.read_csv(path)

# %%
data
# Out:
#        CLIENTNUM  ... Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0      768805383  ...                                           0.999910
# 1      818770008  ...                                           0.999940
# 2      713982108  ...                                           0.999980
# 3      769911858  ...                                           0.999870
# 4      709106358  ...                                           0.999980
# ...          ...  ...                                                ...
# 10122  772366833  ...                                           0.999810
# 10123  710638233  ...                                           0.004729
# 10124  716506083  ...                                           0.002118
# 10125  717406983  ...                                           0.003294
# 10126  714337233  ...                                           0.003377
#
# ...

# %%
data.head()
# Out:
#    CLIENTNUM  ... Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0  768805383  ...                                            0.99991
# 1  818770008  ...                                            0.99994
# 2  713982108  ...                                            0.99998
# 3  769911858  ...                                            0.99987
# 4  709106358  ...                                            0.99998
#
# [5 rows x 23 columns]

# %%
data.tail()
# Out:
#        CLIENTNUM  ... Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 10122  772366833  ...                                           0.999810
# 10123  710638233  ...                                           0.004729
# 10124  716506083  ...                                           0.002118
# 10125  717406983  ...                                           0.003294
# 10126  714337233  ...                                           0.003377
#
# [5 rows x 23 columns]

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (10127, 23)

# %%
plt.scatter(data['CLIENTNUM'],data['Credit_Limit'],c='red')
plt.xlabel('Client Number')
plt.ylabel('Credit Limit')
plt.show()

# %%
plt.hist(data['Credit_Limit'])
plt.show()

# %%
plt.hist(data['Credit_Limit'])
# Out:
# (array([5211., 1524.,  931.,  589.,  407.,  299.,  252.,  161.,  128.,
#          625.]),
#  array([ 1438.3 ,  4746.07,  8053.84, 11361.61, 14669.38, 17977.15,
#         21284.92, 24592.69, 27900.46, 31208.23, 34516.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['Credit_Limit'],color='orange',edgecolor='white',bins=5)
plt.title=("Histogram of Credit Limit")
plt.xlabel("frequencies")
plt.ylabel("Credit Limit")
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['CLIENTNUM'],y=data['Credit_Limit'])

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['CLIENTNUM'],y=data['Credit_Limit'],marker='*',fit_reg=False)

# %%
sns.distplot(data['Credit_Limit'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="Education_Level",data=data)

# %%
sns.boxplot(x=data['CLIENTNUM'],y=data['Education_Level'],data=data)
